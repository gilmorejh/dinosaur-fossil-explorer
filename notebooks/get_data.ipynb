# %%
import requests
import pandas
import json
import os
from pathlib import Path

# %%
#Test endpoint to get a sample of dinosaur occurrence data from the Paleobiology Database API
occurrence_url = "https://paleobiodb.org/data1.2/occs/list.json?base_name=Dinosauria&show=full&vocab=pbdb&limit=10"

response = requests.get(occurrence_url)
response.raise_for_status()

occurrence_data = response.json()

occurrence_df = pandas.DataFrame(occurrence_data["records"])

occurrence_df.head()
# Out:
#   occurrence_no record_type collection_no  \
# 0         41524         occ          3257
# 1         41580         occ          3256
# 2        130209         occ         10755
# 3        130294         occ         10764
# 4        130295         occ         10764
#
#                               identified_name identified_rank  \
# 0                                 Aves indet.           class
# 1                                 Aves indet.           class
# 2  Chaoyangosaurus liaosiensis n. gen. n. sp.         species
# 3    Protarchaeopteryx robusta n. gen. n. sp.         species
# 4             Caudipteryx zoui n. gen. n. sp.         species
#
#                accepted_name     accepted_attr accepted_rank accepted_no  \
# 0                       Aves   (Linnaeus 1758)         class       36616
# 1                       Aves   (Linnaeus 1758)         class       36616
# 2      Chaoyangsaurus youngi  Zhao et al. 1999       species       55580
# 3  Protarchaeopteryx robusta    Ji and Ji 1997       species       66068
# 4           Caudipteryx zoui    Ji et al. 1998       species       66066
#
#       early_interval  ...  spatial_resolution  temporal_resolution  \
# 0           Lutetian  ...                 NaN                  NaN
# 1           Ypresian  ...                 NaN                  NaN
# 2  Late Kimmeridgian  ...                 NaN                  NaN
# 3     Late Barremian  ...                 NaN                  NaN
# 4     Late Barremian  ...                 NaN                  NaN
#
#   concentration reid_no regionalsection regionalbed regionalbedunit  \
# 0           NaN     NaN             NaN         NaN             NaN
# 1           NaN     NaN             NaN         NaN             NaN
# 2           NaN     NaN             NaN         NaN             NaN
# 3           NaN     NaN             NaN         NaN             NaN
# 4           NaN     NaN             NaN         NaN             NaN
#
#   regionalorder articulated_parts museum
# 0           NaN               NaN    NaN
# 1           NaN               NaN    NaN
# 2           NaN               NaN    NaN
# 3           NaN               NaN    NaN
# 4           NaN               NaN    NaN
#
# [5 rows x 87 columns]

# %%
#Retrieve the full dataset of dinosaur occurrences from the Paleobiology Database API
full_url = "https://paleobiodb.org/data1.2/occs/list.json?base_name=Dinosauria&show=full&vocab=pbdb&limit=50000"
response = requests.get(full_url)
response.raise_for_status()

full_data = response.json()
full_df = pandas.DataFrame(full_data['records'])
print(full_df.shape)
# Out:
# (37817, 133)

# %%
#Save as a CSV in data/raw folder
raw_path = Path("..")/"data"/"raw"
full_df.to_csv(raw_path / "phdb_dinosaur_occurrences.csv", index=False)
print((raw_path / "phdb_dinosaur_occurrences.csv").exists())
# Out:
# True

# %% [markdown]
# Source: Paleobiology Database
#
# Endpoint: https://paleobiodb.org/data1.2/occs/list.json
#
# Query:
# base_name=Dinosauria
# show=full
# limit=50000
#
# Records Retrieved:
# 37,816
#
# Columns Retrieved:
# 131
#
# Download Date:
# 8/10/2016
